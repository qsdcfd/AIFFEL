# %%
! mkdir -p ~/aiffel/chest_xray
! ln -s ~/data/ ~/aiffel/chest_xray

# %% [markdown]
# #### 의료 영상 종류
#
# 1. X-RAY
#
# - 전자를 물체에 충돌 시켜서 발생하는 복사선
#
# - 부위별 명암이 다르다
#
# 2. CT
#
# - X-RAY를 빠르게 회전하여 3D이미지 만들어낸다.
#
# 3. MRI
#
# - 강한 자기장을 사용하여 신체 기관 이미지 생성

# %% [markdown]
# #### 영상 촬용
#
# 1. 시상면(Sagittal plane)
#
#   : 사람을 왼쪽과 오른쪽으로 나누는 면
#
# 2. 관상면(Coronal plane)
#
#   : 인체를 앞뒤로 나누는 면
#
# 3. 횡단면(Transverse plane)
#
#   : 인체를 상하로 나누는 면

# %% [markdown]
# ## 폐렴진단
#
# 1. 데이터 셋 : 캐글의 Chest X-RAY Images

# %%
# 사용할 패키지 목록

import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %%
# 필요한 변수 생성
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %%
#데이터 가져오기
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
# 8:2 분할을 위해 train과 val을 합친 후 쪼개기
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
# 정상이미지와 폐렴 이미지 구분
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-0618-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person399_virus_793.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1070
# Pneumonia images count in training set: 3115

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.96
# Weight for PNEUMONIA: 0.67

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 99s 259ms/step - loss: 0.4650 - accuracy: 0.7487 - precision: 0.9404 - recall: 0.7065 - val_loss: 0.6560 - val_accuracy: 0.7327 - val_precision: 0.7327 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 65s 251ms/step - loss: 0.2269 - accuracy: 0.9096 - precision: 0.9745 - recall: 0.9018 - val_loss: 1.0534 - val_accuracy: 0.7327 - val_precision: 0.7327 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 66s 253ms/step - loss: 0.1666 - accuracy: 0.9481 - precision: 0.9841 - recall: 0.9454 - val_loss: 0.4821 - val_accuracy: 0.7798 - val_precision: 0.7689 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 66s 252ms/step - loss: 0.1986 - accuracy: 0.9281 - precision: 0.9767 - recall: 0.9246 - val_loss: 0.1807 - val_accuracy: 0.9317 - val_precision: 0.9986 - val_recall: 0.9084
# Epoch 5/25
# 261/261 [==============================] - 66s 252ms/step - loss: 0.1420 - accuracy: 0.9497 - precision: 0.9856 - recall: 0.9463 - val_loss: 0.2928 - val_accuracy: 0.8952 - val_precision: 0.8757 - val_recall: 0.9987
# Epoch 6/25
# 261/261 [==============================] - 68s 262ms/step - loss: 0.1615 - accuracy: 0.9396 - precision: 0.9836 - recall: 0.9346 - val_loss: 0.1118 - val_accuracy: 0.9548 - val_precision: 0.9945 - val_recall: 0.9436
# Epoch 7/25
# 261/261 [==============================] - 73s 279ms/step - loss: 0.1311 - accuracy: 0.9517 - precision: 0.9886 - recall: 0.9462 - val_loss: 0.1166 - val_accuracy: 0.9567 - val_precision: 0.9454 - val_recall: 0.9987
# Epoch 8/25
# 261/261 [==============================] - 63s 243ms/step - loss: 0.1473 - accuracy: 0.9441 - precision: 0.9825 - recall: 0.9421 - val_loss: 0.0606 - val_accuracy: 0.9837 - val_precision: 0.9870 - val_recall: 0.9909
# Epoch 9/25
# 261/261 [==============================] - 63s 241ms/step - loss: 0.1239 - accuracy: 0.9538 - precision: 0.9902 - recall: 0.9476 - val_loss: 0.0995 - val_accuracy: 0.9673 - val_precision: 0.9596 - val_recall: 0.9974
# Epoch 10/25
# 261/261 [==============================] - 64s 244ms/step - loss: 0.1080 - accuracy: 0.9553 - precision: 0.9888 - recall: 0.9510 - val_loss: 0.3667 - val_accuracy: 0.8654 - val_precision: 0.9984 - val_recall: 0.8183
# Epoch 11/25
# 261/261 [==============================] - 63s 243ms/step - loss: 0.1255 - accuracy: 0.9542 - precision: 0.9888 - recall: 0.9492 - val_loss: 0.0570 - val_accuracy: 0.9779 - val_precision: 0.9881 - val_recall: 0.9817
# Epoch 12/25
# 261/261 [==============================] - 63s 242ms/step - loss: 0.0929 - accuracy: 0.9681 - precision: 0.9910 - recall: 0.9659 - val_loss: 0.0901 - val_accuracy: 0.9702 - val_precision: 0.9633 - val_recall: 0.9974
# Epoch 13/25
# 261/261 [==============================] - 63s 243ms/step - loss: 0.1014 - accuracy: 0.9640 - precision: 0.9904 - recall: 0.9607 - val_loss: 0.1036 - val_accuracy: 0.9635 - val_precision: 0.9538 - val_recall: 0.9987
# Epoch 14/25
# 261/261 [==============================] - 63s 243ms/step - loss: 0.0953 - accuracy: 0.9657 - precision: 0.9928 - recall: 0.9610 - val_loss: 0.0698 - val_accuracy: 0.9760 - val_precision: 0.9682 - val_recall: 1.0000
# Epoch 15/25
# 261/261 [==============================] - 63s 243ms/step - loss: 0.0865 - accuracy: 0.9689 - precision: 0.9908 - recall: 0.9679 - val_loss: 0.0479 - val_accuracy: 0.9817 - val_precision: 0.9895 - val_recall: 0.9856
# Epoch 16/25
# 261/261 [==============================] - 64s 244ms/step - loss: 0.0656 - accuracy: 0.9751 - precision: 0.9947 - recall: 0.9718 - val_loss: 0.1154 - val_accuracy: 0.9625 - val_precision: 0.9526 - val_recall: 0.9987
# Epoch 17/25
# 261/261 [==============================] - 64s 244ms/step - loss: 0.0907 - accuracy: 0.9651 - precision: 0.9927 - recall: 0.9601 - val_loss: 0.1359 - val_accuracy: 0.9394 - val_precision: 0.9986 - val_recall: 0.9187
# Epoch 18/25
# 261/261 [==============================] - 63s 243ms/step - loss: 0.0811 - accuracy: 0.9701 - precision: 0.9922 - recall: 0.9673 - val_loss: 0.1123 - val_accuracy: 0.9663 - val_precision: 0.9572 - val_recall: 0.9987
# Epoch 19/25
# 261/261 [==============================] - 64s 244ms/step - loss: 0.0907 - accuracy: 0.9736 - precision: 0.9902 - recall: 0.9742 - val_loss: 0.1687 - val_accuracy: 0.9346 - val_precision: 0.9181 - val_recall: 1.0000
# Epoch 20/25
# 261/261 [==============================] - 109s 420ms/step - loss: 0.0577 - accuracy: 0.9796 - precision: 0.9940 - recall: 0.9785 - val_loss: 26.3047 - val_accuracy: 0.7337 - val_precision: 0.7337 - val_recall: 1.0000
# Epoch 21/25
# 261/261 [==============================] - 115s 441ms/step - loss: 0.2378 - accuracy: 0.9002 - precision: 0.9705 - recall: 0.8935 - val_loss: 0.3316 - val_accuracy: 0.8779 - val_precision: 0.8573 - val_recall: 1.0000
# Epoch 22/25
# 261/261 [==============================] - 119s 457ms/step - loss: 0.1108 - accuracy: 0.9586 - precision: 0.9845 - recall: 0.9592 - val_loss: 0.0586 - val_accuracy: 0.9788 - val_precision: 0.9744 - val_recall: 0.9974
# Epoch 23/25
# 261/261 [==============================] - 123s 471ms/step - loss: 0.0880 - accuracy: 0.9711 - precision: 0.9950 - recall: 0.9661 - val_loss: 0.0510 - val_accuracy: 0.9779 - val_precision: 0.9907 - val_recall: 0.9790
# Epoch 24/25
# 261/261 [==============================] - 124s 475ms/step - loss: 0.0736 - accuracy: 0.9705 - precision: 0.9931 - recall: 0.9665 - val_loss: 0.1965 - val_accuracy: 0.9481 - val_precision: 0.9339 - val_recall: 1.0000
# Epoch 25/25
# 261/261 [==============================] - 119s 457ms/step - loss: 0.0685 - accuracy: 0.9722 - precision: 0.9919 - recall: 0.9707 - val_loss: 0.0692 - val_accuracy: 0.9702 - val_precision: 1.0000 - val_recall: 0.9593

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 12s 285ms/step - loss: 0.6877 - accuracy: 0.8478 - precision: 0.8132 - recall: 0.9821
# Loss: 0.6876684427261353,
# Accuracy: 0.8477563858032227,
# Precision: 0.8131634593009949,
# Recall: 0.9820512533187866
