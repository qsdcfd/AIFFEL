# %%
! mkdir -p ~/aiffel/rock_scissor_paper4/scissor4
! mkdir -p ~/aiffel/rock_scissor_paper4/rock4
! mkdir -p ~/aiffel/rock_scissor_paper4/paper4

! ls -l ~/aiffel/rock_scissor_paper4
# Out:
# total 12
# drwxr-xr-x 2 root root 4096 Sep 24 08:53 paper4
# drwxr-xr-x 2 root root 4096 Sep 24 08:53 rock4
# drwxr-xr-x 2 root root 4096 Sep 24 08:53 scissor4

# %%
! unzip ~/aiffel/rock_scissor_paper4/rock4/rock.zip -d ~/aiffel/rock_scissor_paper4/rock4
# Out:
# Archive:  /aiffel/aiffel/rock_scissor_paper4/rock4/rock.zip
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (1).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (10).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (100).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (1000).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (1001).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (1002).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (1003).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (1004).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (1005).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (1006).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (1007).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (1008).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/rock4/a_ (1009).jpg
# ...

# %%
! unzip ~/aiffel/rock_scissor_paper4/scissor4/scissor.zip -d ~/aiffel/rock_scissor_paper4/scissor4
# Out:
# Archive:  /aiffel/aiffel/rock_scissor_paper4/scissor4/scissor.zip
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (1).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (10).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (100).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (1000).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (1001).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (1002).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (1003).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (1004).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (1005).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (1006).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (1007).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/scissor4/a_ (1008).jpg
# ...

# %%
! unzip ~/aiffel/rock_scissor_paper4/paper4/paper.zip -d ~/aiffel/rock_scissor_paper4/paper4
# Out:
# Archive:  /aiffel/aiffel/rock_scissor_paper4/paper4/paper.zip
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (1).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (10).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (100).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (1000).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (1001).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (1002).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (1003).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (1004).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (1005).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (1006).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (1007).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (1008).jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/paper4/a_ (1009).jpg
# ...

# %%
from PIL import Image
import os, glob

print("PIL 라이브러리 import 완료!")
# Out:
# PIL 라이브러리 import 완료!

# %%
import os

def resize_images(img_path):
	images=glob.glob(img_path + "/*.jpg")  
    
	print(len(images), " images to be resized.")

    # 파일마다 모두 28x28 사이즈로 바꾸어 저장합니다.
	target_size=(28,28)
	for img in images:
		old_img=Image.open(img)
		new_img=old_img.resize(target_size,Image.ANTIALIAS)
		new_img.save(img, "JPEG")
    
	print(len(images), " images resized.")
	
# 가위 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
image_dir_path = os.getenv("HOME") + "/aiffel/rock_scissor_paper4/scissor4"
resize_images(image_dir_path)

print("가위 이미지 resize 완료!")
# Out:
# 1200  images to be resized.
# 1200  images resized.
# 가위 이미지 resize 완료!

# %%
import os

def resize_images(img_path):
	images=glob.glob(img_path + "/*.jpg")  
    
	print(len(images), " images to be resized.")

    # 파일마다 모두 28x28 사이즈로 바꾸어 저장합니다.
	target_size=(28,28)
	for img in images:
		old_img=Image.open(img)
		new_img=old_img.resize(target_size,Image.ANTIALIAS)
		new_img.save(img, "JPEG")
    
	print(len(images), " images resized.")
	
# 바위 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
image_dir_path = os.getenv("HOME") + "/aiffel/rock_scissor_paper4/rock4"
resize_images(image_dir_path)

print("바위 이미지 resize 완료!")
# Out:
# 1200  images to be resized.
# 1200  images resized.
# 바위 이미지 resize 완료!

# %%
import os

def resize_images(img_path):
	images=glob.glob(img_path + "/*.jpg")  
    
	print(len(images), " images to be resized.")

    # 파일마다 모두 28x28 사이즈로 바꾸어 저장합니다.
	target_size=(28,28)
	for img in images:
		old_img=Image.open(img)
		new_img=old_img.resize(target_size,Image.ANTIALIAS)
		new_img.save(img, "JPEG")
    
	print(len(images), " images resized.")
	
# 보 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
image_dir_path = os.getenv("HOME") + "/aiffel/rock_scissor_paper4/paper4"
resize_images(image_dir_path)

print("보 이미지 resize 완료!")
# Out:
# 1200  images to be resized.
# 1200  images resized.
# 보 이미지 resize 완료!

# %% [markdown]
# 평가문항 1번

# %%
import numpy as np

def load_data(img_path, number_of_data=3600):  # 가위바위보 이미지 개수 총합에 주의하세요.
    # 가위 : 0, 바위 : 1, 보 : 2
    img_size=28
    color=3
    #이미지 데이터와 라벨(가위 : 0, 바위 : 1, 보 : 2) 데이터를 담을 행렬(matrix) 영역을 생성합니다.
    imgs=np.zeros(number_of_data*img_size*img_size*color,dtype=np.int32).reshape(number_of_data,img_size,img_size,color)
    labels=np.zeros(number_of_data,dtype=np.int32)

    idx=0
    for file in glob.iglob(img_path+'/scissor4/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=0   # 가위 : 0
        idx=idx+1

    for file in glob.iglob(img_path+'/rock4/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=1   # 바위 : 1
        idx=idx+1  
    
    for file in glob.iglob(img_path+'/paper4/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=2   # 보 : 2
        idx=idx+1
        
    print("학습데이터(x_train)의 이미지 개수는", idx,"입니다.")
    return imgs, labels

image_dir_path = os.getenv("HOME") + "/aiffel/rock_scissor_paper4"
(x_train, y_train)=load_data(image_dir_path)
x_train_norm = x_train/255.0   # 입력은 0~1 사이의 값으로 정규화

print("x_train shape: {}".format(x_train.shape))
print("y_train shape: {}".format(y_train.shape))
# Out:
# 학습데이터(x_train)의 이미지 개수는 3600 입니다.
# x_train shape: (3600, 28, 28, 3)
# y_train shape: (3600,)

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[0])
print('라벨: ', y_train[0])
# Out:
# 라벨:  0

# %% [markdown]
# 평가문항 2번

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

n_channel_1=16
n_channel_2=32
n_dense=64
n_train_epoch=15

model=keras.models.Sequential()
model.add(keras.layers.Conv2D(n_channel_1, (3,3), activation='relu', input_shape=(28,28,3)))
model.add(keras.layers.MaxPool2D(2,2))
model.add(keras.layers.Conv2D(n_channel_2, (3,3), activation='relu'))
model.add(keras.layers.MaxPooling2D((2,2)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(n_dense, activation='relu'))
model.add(keras.layers.Dense(3, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_16 (Conv2D)           (None, 26, 26, 16)        448
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 11, 11, 32)        4640
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                51264
# _________________________________________________________________
# dense_17 (Dense)             (None, 3)                 195
# ...

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(x_train_norm, y_train, epochs=n_train_epoch)
# Out:
# Epoch 1/15
# 113/113 [==============================] - 1s 3ms/step - loss: 1.0658 - accuracy: 0.4203
# Epoch 2/15
# 113/113 [==============================] - 0s 3ms/step - loss: 0.8249 - accuracy: 0.6331
# Epoch 3/15
# 113/113 [==============================] - 0s 3ms/step - loss: 0.5553 - accuracy: 0.7962
# Epoch 4/15
# 113/113 [==============================] - 0s 3ms/step - loss: 0.3868 - accuracy: 0.8661
# Epoch 5/15
# 113/113 [==============================] - 0s 3ms/step - loss: 0.2893 - accuracy: 0.8986
# Epoch 6/15
# 113/113 [==============================] - 0s 3ms/step - loss: 0.2202 - accuracy: 0.9272
# Epoch 7/15
# 113/113 [==============================] - 0s 3ms/step - loss: 0.1574 - accuracy: 0.9549
# Epoch 8/15
# 113/113 [==============================] - 0s 3ms/step - loss: 0.1510 - accuracy: 0.9574
# Epoch 9/15
# 113/113 [==============================] - 0s 3ms/step - loss: 0.1012 - accuracy: 0.9737
# Epoch 10/15
# ...

# %%
! mkdir -p ~/aiffel/rock_scissor_paper4/test4

# %%
! mkdir -p ~/aiffel/rock_scissor_paper4/test4/scissor4
! mkdir -p ~/aiffel/rock_scissor_paper4/test4/rock4
! mkdir -p ~/aiffel/rock_scissor_paper4/test4/paper4

! ls -l ~/aiffel/rock_scissor_paper4/test4
# Out:
# total 12
# drwxr-xr-x 2 root root 4096 Sep 24 11:58 paper4
# drwxr-xr-x 2 root root 4096 Sep 24 11:58 rock4
# drwxr-xr-x 2 root root 4096 Sep 24 11:58 scissor4

# %%
! unzip ~/aiffel/rock_scissor_paper4/test4/rock4/rock.zip -d ~/aiffel/rock_scissor_paper4/test4/rock4
# Out:
# Archive:  /aiffel/aiffel/rock_scissor_paper4/test4/rock4/rock.zip
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/100.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/101.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/102.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/103.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/24.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/25.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/26.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/27.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/28.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/29.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/30.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/31.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/rock4/32.jpg
# ...

# %%
! unzip ~/aiffel/rock_scissor_paper4/test4/scissor4/scissor.zip -d ~/aiffel/rock_scissor_paper4/test4/scissor4
# Out:
# Archive:  /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/scissor.zip
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/20.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/21.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/22.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/23.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/24.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/25.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/26.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/27.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/28.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/29.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/30.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/scissor4/31.jpg
# ...

# %%
! unzip ~/aiffel/rock_scissor_paper4/test4/paper4/paper.zip -d ~/aiffel/rock_scissor_paper4/test4/paper4
# Out:
# Archive:  /aiffel/aiffel/rock_scissor_paper4/test4/paper4/paper.zip
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/110.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/111.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/20.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/21.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/22.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/23.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/24.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/25.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/26.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/27.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/28.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/29.jpg
#   inflating: /aiffel/aiffel/rock_scissor_paper4/test4/paper4/30.jpg
# ...

# %%
image_dir_path = os.getenv("HOME") + "/aiffel/rock_scissor_paper4/test4"
(x_test, y_test)=load_data(image_dir_path, 240)
x_test_norm = x_test/255.0

print("x_train shape {}".format(x_test.shape))
print("y_train shape {}".format(y_test.shape))
# Out:
# 학습데이터(x_train)의 이미지 개수는 240 입니다.
# x_train shape (240, 28, 28, 3)
# y_train shape (240,)

# %% [markdown]
# 평가문항 3번. Accuracy가 60%이상 도달했습니다.

# %%
test_loss, test_accuracy = model.evaluate(x_test_norm, y_test, verbose=2)
print("test_loss: {}".format(test_loss))
print("test_accuracy: {}".format(test_accuracy))
# Out:
# 8/8 - 0s - loss: 1.3255 - accuracy: 0.6208
# test_loss: 1.3255308866500854
# test_accuracy: 0.6208333373069763

# %% [markdown]
# [첫 Exploration 회고]
#
# -느낀점:
# 처음이라 많은 실수를 하고 구글링과 퍼실님들께 질문을
# 많이 한 것 같습니다. 기타 등등의 실수를 통해서 왜 그런 결과가 나왔고 다시는 이런 실수를 반복하지 않을겁니다
# 허나 처음으로 짧지만 프로젝트를 끝내어서 작은 성취감을 얻게 되어서 기뻤습니다. 나중에는 좀 더 어렵고 실생활에 쓰이는 것을 정확도를 높여서 만들고 싶습니다.
#
# -실수
#
# 1.정규화를 하지 않고 데이터를 출력하려고 했습니다
#
# 2.훈련데이터와 테스트 데이터 구분하지 않아서
# 정확성이 1.0이 나왔습니다
#
# 3.테스트 데이터 파일을 만들지 않고 코드 실행으로 정확성 0이 나왔습니다.
